# %% [markdown]
# # NLP_Tp1_Spacy_En
#
# ## load data

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
import spacy
from spacy import displacy 
nlp = spacy.load('en_core_web_sm')
text = nlp("""Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely
the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from
the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowed rational
numbers, irrational numbers, geometrical magnitudes, etc., to all be treated as "algebraic objects". It gave mathematics a whole new
development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the
subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itself in a
way which had not happened before.""")

# %% [markdown]
# # Tokenization et pos tagging

# %%
for t in text:
    print(t.text,":",t.pos_, ":",t.tag_)
# Out:
# Perhaps : ADV : RB
# one : NUM : CD
# of : ADP : IN
# the : DET : DT
# most : ADV : RBS
# significant : ADJ : JJ
# advances : NOUN : NNS
# made : VERB : VBN
# by : ADP : IN
# Arabic : ADJ : JJ
# mathematics : NOUN : NNS
# began : VERB : VBD
# at : ADP : IN
# this : DET : DT
# time : NOUN : NN
# with : ADP : IN
# the : DET : DT
# work : NOUN : NN
# of : ADP : IN
# al : PROPN : NNP
# - : PUNCT : HYPH
# Khwarizmi : PROPN : NNP
# , : PUNCT : ,
# namely : ADV : RB
#
#  : SPACE : _SP
# the : DET : DT
# beginnings : NOUN : NNS
# of : ADP : IN
# algebra : NOUN : NNS
# . : PUNCT : .
# It : PRON : PRP
# is : AUX : VBZ
# important : ADJ : JJ
# to : PART : TO
# understand : VERB : VB
# just : ADV : RB
# how : ADV : WRB
# significant : ADJ : JJ
# this : DET : DT
# new : ADJ : JJ
# idea : NOUN : NN
# was : AUX : VBD
# . : PUNCT : .
# It : PRON : PRP
# was : AUX : VBD
# a : DET : DT
# revolutionary : ADJ : JJ
# move : NOUN : NN
# away : ADV : RB
# from : ADP : IN
#
#  : SPACE : _SP
# the : DET : DT
# Greek : ADJ : JJ
# concept : NOUN : NN
# of : ADP : IN
# mathematics : NOUN : NNS
# which : DET : WDT
# was : VERB : VBD
# essentially : ADV : RB
# geometry : NOUN : NN
# . : PUNCT : .
# Algebra : PROPN : NNP
# was : AUX : VBD
# a : DET : DT
# unifying : ADJ : JJ
# theory : NOUN : NN
# which : DET : WDT
# allowed : VERB : VBD
# rational : ADJ : JJ
#
#  : SPACE : _SP
# numbers : NOUN : NNS
# , : PUNCT : ,
# irrational : ADJ : JJ
# numbers : NOUN : NNS
# , : PUNCT : ,
# geometrical : ADJ : JJ
# magnitudes : NOUN : NNS
# , : PUNCT : ,
# etc : X : FW
# . : X : FW
# , : PUNCT : ,
# to : ADP : IN
# all : DET : DT
# be : AUX : VB
# treated : VERB : VBN
# as : ADP : IN
# " : PUNCT : ``
# algebraic : ADJ : JJ
# objects : NOUN : NNS
# " : PUNCT : ''
# . : PUNCT : .
# It : PRON : PRP
# gave : VERB : VBD
# mathematics : NOUN : NNS
# a : DET : DT
# whole : ADJ : JJ
# new : ADJ : JJ
#
#  : SPACE : _SP
# development : NOUN : NN
# path : NOUN : NN
# so : ADV : RB
# much : ADV : RB
# broader : ADJ : JJR
# in : ADP : IN
# concept : NOUN : NN
# to : ADP : IN
# that : DET : DT
# which : DET : WDT
# had : AUX : VBD
# existed : VERB : VBN
# before : ADV : RB
# , : PUNCT : ,
# and : CCONJ : CC
# provided : VERB : VBD
# a : DET : DT
# vehicle : NOUN : NN
# for : ADP : IN
# future : ADJ : JJ
# development : NOUN : NN
# of : ADP : IN
# the : DET : DT
#
#  : SPACE : _SP
# subject : NOUN : NN
# . : PUNCT : .
# Another : DET : DT
# important : ADJ : JJ
# aspect : NOUN : NN
# of : ADP : IN
# the : DET : DT
# introduction : NOUN : NN
# of : ADP : IN
# algebraic : ADJ : JJ
# ideas : NOUN : NNS
# was : AUX : VBD
# that : SCONJ : IN
# it : PRON : PRP
# allowed : VERB : VBD
# mathematics : NOUN : NNS
# to : PART : TO
# be : AUX : VB
# applied : VERB : VBN
# to : ADP : IN
# itself : PRON : PRP
# in : ADP : IN
# a : DET : DT
#
#  : SPACE : _SP
# way : NOUN : NN
# which : DET : WDT
# had : AUX : VBD
# not : PART : RB
# happened : VERB : VBN
# before : ADV : RB
# . : PUNCT : .

# %% [markdown]
# [texte du lien](https://) # Lemmatization

# %%
for word in text:
    print(word.text,  ":" , word.lemma_ )
# Out:
# Perhaps : perhaps
# one : one
# of : of
# the : the
# most : most
# significant : significant
# advances : advance
# made : make
# by : by
# Arabic : arabic
# mathematics : mathematic
# began : begin
# at : at
# this : this
# time : time
# with : with
# the : the
# work : work
# of : of
# al : al
# - : -
# Khwarizmi : Khwarizmi
# , : ,
# namely : namely
#
#  :
#
# the : the
# beginnings : beginning
# of : of
# algebra : algebra
# . : .
# It : it
# is : be
# important : important
# to : to
# understand : understand
# just : just
# how : how
# significant : significant
# this : this
# new : new
# idea : idea
# was : be
# . : .
# It : it
# was : be
# a : a
# revolutionary : revolutionary
# move : move
# away : away
# from : from
#
#  :
#
# the : the
# Greek : greek
# concept : concept
# of : of
# mathematics : mathematic
# which : which
# was : be
# essentially : essentially
# geometry : geometry
# . : .
# Algebra : Algebra
# was : be
# a : a
# unifying : unifying
# theory : theory
# which : which
# allowed : allow
# rational : rational
#
#  :
#
# numbers : number
# , : ,
# irrational : irrational
# numbers : number
# , : ,
# geometrical : geometrical
# magnitudes : magnitude
# , : ,
# etc : etc
# . : .
# , : ,
# to : to
# all : all
# be : be
# treated : treat
# as : as
# " : "
# algebraic : algebraic
# objects : object
# " : "
# . : .
# It : it
# gave : give
# mathematics : mathematic
# a : a
# whole : whole
# new : new
#
#  :
#
# development : development
# path : path
# so : so
# much : much
# broader : broad
# in : in
# concept : concept
# to : to
# that : that
# which : which
# had : have
# existed : exist
# before : before
# , : ,
# and : and
# provided : provide
# a : a
# vehicle : vehicle
# for : for
# future : future
# development : development
# of : of
# the : the
#
#  :
#
# subject : subject
# . : .
# Another : another
# important : important
# aspect : aspect
# of : of
# the : the
# introduction : introduction
# of : of
# algebraic : algebraic
# ideas : idea
# was : be
# that : that
# it : it
# allowed : allow
# mathematics : mathematic
# to : to
# be : be
# applied : apply
# to : to
# itself : itself
# in : in
# a : a
#
#  :
#
# way : way
# which : which
# had : have
# not : not
# happened : happen
# before : before
# . : .

# %% [markdown]
#  # Stemming

# %%
 
p_stemmer = PorterStemmer()
for words in text :
    print(words.text + '---------' + p_stemmer.stem(words.text))
# Out:
# Perhaps---------perhap
# one---------one
# of---------of
# the---------the
# most---------most
# significant---------signific
# advances---------advanc
# made---------made
# by---------by
# Arabic---------arab
# mathematics---------mathemat
# began---------began
# at---------at
# this---------thi
# time---------time
# with---------with
# the---------the
# work---------work
# of---------of
# al---------al
# -----------
# Khwarizmi---------khwarizmi
# ,---------,
# namely---------name
#
# ---------
#
# the---------the
# beginnings---------begin
# of---------of
# algebra---------algebra
# .---------.
# It---------it
# is---------is
# important---------import
# to---------to
# understand---------understand
# just---------just
# how---------how
# significant---------signific
# this---------thi
# new---------new
# idea---------idea
# was---------wa
# .---------.
# It---------it
# was---------wa
# a---------a
# revolutionary---------revolutionari
# move---------move
# away---------away
# from---------from
#
# ---------
#
# the---------the
# Greek---------greek
# concept---------concept
# of---------of
# mathematics---------mathemat
# which---------which
# was---------wa
# essentially---------essenti
# geometry---------geometri
# .---------.
# Algebra---------algebra
# was---------wa
# a---------a
# unifying---------unifi
# theory---------theori
# which---------which
# allowed---------allow
# rational---------ration
#
# ---------
#
# numbers---------number
# ,---------,
# irrational---------irrat
# numbers---------number
# ,---------,
# geometrical---------geometr
# magnitudes---------magnitud
# ,---------,
# etc---------etc
# .---------.
# ,---------,
# to---------to
# all---------all
# be---------be
# treated---------treat
# as---------as
# "---------"
# algebraic---------algebra
# objects---------object
# "---------"
# .---------.
# It---------it
# gave---------gave
# mathematics---------mathemat
# a---------a
# whole---------whole
# new---------new
#
# ---------
#
# development---------develop
# path---------path
# so---------so
# much---------much
# broader---------broader
# in---------in
# concept---------concept
# to---------to
# that---------that
# which---------which
# had---------had
# existed---------exist
# before---------befor
# ,---------,
# and---------and
# provided---------provid
# a---------a
# vehicle---------vehicl
# for---------for
# future---------futur
# development---------develop
# of---------of
# the---------the
#
# ---------
#
# subject---------subject
# .---------.
# Another---------anoth
# important---------import
# aspect---------aspect
# of---------of
# the---------the
# introduction---------introduct
# of---------of
# algebraic---------algebra
# ideas---------idea
# was---------wa
# that---------that
# it---------it
# allowed---------allow
# mathematics---------mathemat
# to---------to
# be---------be
# applied---------appli
# to---------to
# itself---------itself
# in---------in
# a---------a
#
# ---------
#
# way---------way
# which---------which
# had---------had
# not---------not
# happened---------happen
# before---------befor
# .---------.

# %% [markdown]
# # chunking

# %%
for chunk in text.noun_chunks:
    print(chunk.text,chunk.label_,chunk.root.text)
# Out:
# the most significant advances NP advances
# Arabic mathematics NP mathematics
# this time NP time
# the work NP work
# al-Khwarizmi NP Khwarizmi
# the beginnings NP beginnings
# algebra NP algebra
# It NP It
# this new idea NP idea
# It NP It
# a revolutionary move NP move
# the Greek concept NP concept
# mathematics NP mathematics
# essentially geometry NP geometry
# Algebra NP Algebra
# a unifying theory NP theory
# rational
# numbers NP numbers
# irrational numbers NP numbers
# geometrical magnitudes NP magnitudes
# "algebraic objects NP objects
# It NP It
# mathematics NP mathematics
# a whole new
# development path NP path
# concept NP concept
# a vehicle NP vehicle
# future development NP development
# the
# subject NP subject
# Another important aspect NP aspect
# the introduction NP introduction
# algebraic ideas NP ideas
# it NP it
# mathematics NP mathematics
# itself NP itself
# a
# way NP way

# %%
for token in text:
    print("{0}/{1} <-- {2} <-- {3}/{4}".format(
    token.text, token.tag_, token.dep_, token.head.text, token.head.tag_) )
# Out:
# Perhaps/RB <-- advmod <-- began/VBD
# one/CD <-- nsubj <-- began/VBD
# of/IN <-- prep <-- one/CD
# the/DT <-- det <-- advances/NNS
# most/RBS <-- advmod <-- significant/JJ
# significant/JJ <-- amod <-- advances/NNS
# advances/NNS <-- pobj <-- of/IN
# made/VBN <-- acl <-- advances/NNS
# by/IN <-- agent <-- made/VBN
# Arabic/JJ <-- amod <-- mathematics/NNS
# mathematics/NNS <-- pobj <-- by/IN
# began/VBD <-- ROOT <-- began/VBD
# at/IN <-- prep <-- began/VBD
# this/DT <-- det <-- time/NN
# time/NN <-- pobj <-- at/IN
# with/IN <-- prep <-- began/VBD
# the/DT <-- det <-- work/NN
# work/NN <-- pobj <-- with/IN
# of/IN <-- prep <-- work/NN
# al/NNP <-- compound <-- Khwarizmi/NNP
# -/HYPH <-- punct <-- Khwarizmi/NNP
# Khwarizmi/NNP <-- pobj <-- of/IN
# ,/, <-- punct <-- work/NN
# namely/RB <-- advmod <--
# /_SP
#
# /_SP <-- punct <-- began/VBD
# the/DT <-- det <-- beginnings/NNS
# beginnings/NNS <-- dobj <-- began/VBD
# of/IN <-- prep <-- beginnings/NNS
# algebra/NNS <-- pobj <-- of/IN
# ./. <-- punct <-- began/VBD
# It/PRP <-- nsubj <-- is/VBZ
# is/VBZ <-- ROOT <-- is/VBZ
# important/JJ <-- acomp <-- is/VBZ
# to/TO <-- aux <-- understand/VB
# understand/VB <-- xcomp <-- is/VBZ
# just/RB <-- advmod <-- significant/JJ
# how/WRB <-- advmod <-- significant/JJ
# significant/JJ <-- acomp <-- was/VBD
# this/DT <-- det <-- idea/NN
# new/JJ <-- amod <-- idea/NN
# idea/NN <-- nsubj <-- was/VBD
# was/VBD <-- ccomp <-- understand/VB
# ./. <-- punct <-- is/VBZ
# It/PRP <-- nsubj <-- was/VBD
# was/VBD <-- ROOT <-- was/VBD
# a/DT <-- det <-- move/NN
# revolutionary/JJ <-- amod <-- move/NN
# move/NN <-- attr <-- was/VBD
# away/RB <-- advmod <-- move/NN
# from/IN <-- prep <-- away/RB
#
# /_SP <-- punct <-- from/IN
# the/DT <-- det <-- concept/NN
# Greek/JJ <-- amod <-- concept/NN
# concept/NN <-- pobj <-- from/IN
# of/IN <-- prep <-- concept/NN
# mathematics/NNS <-- pobj <-- of/IN
# which/WDT <-- nsubj <-- was/VBD
# was/VBD <-- relcl <-- concept/NN
# essentially/RB <-- advmod <-- geometry/NN
# geometry/NN <-- attr <-- was/VBD
# ./. <-- punct <-- was/VBD
# Algebra/NNP <-- nsubj <-- was/VBD
# was/VBD <-- ROOT <-- was/VBD
# a/DT <-- det <-- theory/NN
# unifying/JJ <-- amod <-- theory/NN
# theory/NN <-- attr <-- was/VBD
# which/WDT <-- nsubj <-- allowed/VBD
# allowed/VBD <-- relcl <-- theory/NN
# rational/JJ <-- amod <-- numbers/NNS
#
# /_SP <-- punct <-- numbers/NNS
# numbers/NNS <-- dobj <-- allowed/VBD
# ,/, <-- punct <-- numbers/NNS
# irrational/JJ <-- amod <-- numbers/NNS
# numbers/NNS <-- conj <-- numbers/NNS
# ,/, <-- punct <-- numbers/NNS
# geometrical/JJ <-- amod <-- magnitudes/NNS
# magnitudes/NNS <-- conj <-- numbers/NNS
# ,/, <-- punct <-- magnitudes/NNS
# etc/FW <-- conj <-- magnitudes/NNS
# ./FW <-- conj <-- magnitudes/NNS
# ,/, <-- punct <-- theory/NN
# to/IN <-- prep <-- treated/VBN
# all/DT <-- nsubjpass <-- treated/VBN
# be/VB <-- auxpass <-- treated/VBN
# treated/VBN <-- advcl <-- was/VBD
# as/IN <-- prep <-- treated/VBN
# "/`` <-- punct <-- objects/NNS
# algebraic/JJ <-- amod <-- objects/NNS
# objects/NNS <-- pobj <-- as/IN
# "/'' <-- punct <-- objects/NNS
# ./. <-- punct <-- was/VBD
# It/PRP <-- nsubj <-- gave/VBD
# gave/VBD <-- ROOT <-- gave/VBD
# mathematics/NNS <-- dative <-- gave/VBD
# a/DT <-- det <-- path/NN
# whole/JJ <-- amod <-- path/NN
# new/JJ <-- amod <-- path/NN
#
# /_SP <-- compound <-- path/NN
# development/NN <-- compound <-- path/NN
# path/NN <-- dobj <-- gave/VBD
# so/RB <-- advmod <-- much/RB
# much/RB <-- advmod <-- broader/JJR
# broader/JJR <-- dobj <-- gave/VBD
# in/IN <-- prep <-- broader/JJR
# concept/NN <-- pobj <-- in/IN
# to/IN <-- prep <-- concept/NN
# that/DT <-- pobj <-- to/IN
# which/WDT <-- nsubj <-- existed/VBN
# had/VBD <-- aux <-- existed/VBN
# existed/VBN <-- relcl <-- that/DT
# before/RB <-- advmod <-- existed/VBN
# ,/, <-- punct <-- gave/VBD
# and/CC <-- cc <-- gave/VBD
# provided/VBD <-- conj <-- gave/VBD
# a/DT <-- det <-- vehicle/NN
# vehicle/NN <-- dobj <-- provided/VBD
# for/IN <-- prep <-- vehicle/NN
# future/JJ <-- amod <-- development/NN
# development/NN <-- pobj <-- for/IN
# of/IN <-- prep <-- development/NN
# the/DT <-- det <-- subject/NN
#
# /_SP <-- compound <-- subject/NN
# subject/NN <-- pobj <-- of/IN
# ./. <-- punct <-- gave/VBD
# Another/DT <-- det <-- aspect/NN
# important/JJ <-- amod <-- aspect/NN
# aspect/NN <-- nsubj <-- was/VBD
# of/IN <-- prep <-- aspect/NN
# the/DT <-- det <-- introduction/NN
# introduction/NN <-- pobj <-- of/IN
# of/IN <-- prep <-- introduction/NN
# algebraic/JJ <-- amod <-- ideas/NNS
# ideas/NNS <-- pobj <-- of/IN
# was/VBD <-- ROOT <-- was/VBD
# that/IN <-- mark <-- allowed/VBD
# it/PRP <-- nsubj <-- allowed/VBD
# allowed/VBD <-- ccomp <-- was/VBD
# mathematics/NNS <-- nsubjpass <-- applied/VBN
# to/TO <-- aux <-- applied/VBN
# be/VB <-- auxpass <-- applied/VBN
# applied/VBN <-- ccomp <-- allowed/VBD
# to/IN <-- prep <-- applied/VBN
# itself/PRP <-- pobj <-- to/IN
# in/IN <-- prep <-- applied/VBN
# a/DT <-- det <-- way/NN
#
# /_SP <-- compound <-- way/NN
# way/NN <-- pobj <-- in/IN
# which/WDT <-- nsubj <-- happened/VBN
# had/VBD <-- aux <-- happened/VBN
# not/RB <-- neg <-- happened/VBN
# happened/VBN <-- relcl <-- way/NN
# before/RB <-- advmod <-- happened/VBN
# ./. <-- punct <-- was/VBD

# %% [markdown]
# # parsing

# %%
#parsing visualistation
displacy.render(text, style='dep', jupyter = True, options={'distance' : 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="53664207385046e6a04e645c34dadbeb-0" class="displacy" width="13750" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Perhaps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">significant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">advances</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">made</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Arabic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">mathematics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">began</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">time</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">work</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">al-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">Khwarizmi,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">namely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">beginnings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">algebra.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">important</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PART<

# %%
entities=[(i, i.label_, i.label) for i in text.ents]
entities
# Out:
# [(Arabic, 'NORP', 381), (al-Khwarizmi, 'GPE', 384), (Greek, 'NORP', 381)]
